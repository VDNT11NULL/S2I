# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.1)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.9 MB/s eta 0:00:00
# Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 23.6 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 optuna-4.0.0

# %%
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
from tqdm import tqdm
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from utils import save_some_examples
from UvU_Net_Generator import OuterUNet as Generator
from Pix_Discriminator import Discriminator
import config

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

class PairedImageDataset(Dataset):
    def __init__(self, input_dir, target_dir, transform=None):
        self.input_dir = input_dir
        self.target_dir = target_dir
        self.input_images = sorted(os.listdir(input_dir))
        self.target_images = sorted(os.listdir(target_dir))
        self.transform = transform

        assert len(self.input_images) == len(self.target_images), "Mismatch between input and target images!"

    def __len__(self):
        return len(self.input_images)

    def __getitem__(self, idx):
        input_image_path = os.path.join(self.input_dir, self.input_images[idx])
        target_image_path = os.path.join(self.target_dir, self.target_images[idx])

        input_image = Image.open(input_image_path).convert("RGB")
        target_image = Image.open(target_image_path).convert("RGB")

        if self.transform:
            input_image = self.transform(input_image)
            target_image = self.transform(target_image)

        return input_image, target_image

def train_fn(
    disc, gen, loader, opt_disc, opt_gen, l1_loss, bce, g_scaler, d_scaler,
):
    loop = tqdm(loader, leave=True)

    for idx, (x, y) in enumerate(loop):
        x = x.to(config.DEVICE)
        y = y.to(config.DEVICE)

        # Train Discriminator
        with torch.cuda.amp.autocast():
            y_fake = gen(x)
            D_real = disc(x, y)
            D_real_loss = bce(D_real, torch.ones_like(D_real))
            D_fake = disc(x, y_fake.detach())
            D_fake_loss = bce(D_fake, torch.zeros_like(D_fake))
            D_loss = (D_real_loss + D_fake_loss) / 2

        disc.zero_grad()
        d_scaler.scale(D_loss).backward()
        d_scaler.step(opt_disc)
        d_scaler.update()

        # Train generator
        with torch.cuda.amp.autocast():
            D_fake = disc(x, y_fake)
            G_fake_loss = bce(D_fake, torch.ones_like(D_fake))
            L1 = l1_loss(y_fake, y) * config.L1_LAMBDA
            G_loss = G_fake_loss + L1

        opt_gen.zero_grad()
        g_scaler.scale(G_loss).backward()
        g_scaler.step(opt_gen)
        g_scaler.update()

        if idx % 10 == 0:
            loop.set_postfix(
                D_real=torch.sigmoid(D_real).mean().item(),
                D_fake=torch.sigmoid(D_fake).mean().item(),
            )


# Objective function for Optuna
def objective(trial):
    # Hyperparameters to tune
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-3)
    batch_size = trial.suggest_categorical('batch_size', [8, 16, 32])
    l1_lambda = trial.suggest_int('l1_lambda', 10, 200)
    lambda_gp = trial.suggest_int('lambda_gp', 1, 10)
    num_epochs = trial.suggest_int('num_epochs', 5, 50)

    # Dataset and DataLoader preparation
    input_dir = '/content/Canny'
    target_dir = '/content/Target'

    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
    ])

    dataset = PairedImageDataset(input_dir=input_dir, target_dir=target_dir, transform=transform)
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

    # Initialize models, optimizers, and losses
    disc = Discriminator(in_channels=3).to(DEVICE)
    gen = Generator(in_channels=3, features=64).to(DEVICE)
    opt_disc = optim.Adam(disc.parameters(), lr=learning_rate, betas=(0.5, 0.999))
    opt_gen = optim.Adam(gen.parameters(), lr=learning_rate, betas=(0.5, 0.999))

    BCE = nn.BCEWithLogitsLoss()
    L1_LOSS = nn.L1Loss()
    g_scaler = torch.cuda.amp.GradScaler()
    d_scaler = torch.cuda.amp.GradScaler()

    # Train the model and calculate validation loss
    for epoch in range(num_epochs):
        train_fn(
            disc, gen, train_loader, opt_disc, opt_gen, L1_LOSS, BCE, g_scaler, d_scaler,
        )

    # Evaluate the model on the validation set
    total_loss = 0
    gen.eval()
    with torch.no_grad():
        for input_image, target_image in val_loader:
            input_image, target_image = input_image.to(DEVICE), target_image.to(DEVICE)
            y_fake = gen(input_image)
            loss = L1_LOSS(y_fake, target_image) * l1_lambda
            total_loss += loss.item()

    # Return average validation loss to minimize
    return total_loss / len(val_loader)

# Run Optuna study
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize")  # We want to minimize the loss
    study.optimize(objective, n_trials=20)  # Run 20 trials

    # Print best hyperparameters
    print("Best Hyperparameters: ", study.best_params)
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# [I 2024-10-18 18:30:07,501] A new study created in memory with name: no-name-6340c6c3-f11a-48ae-9ed2-e19c5c5297f5
# torch.Size([1, 3, 512, 512])
# <ipython-input-2-f2927eac8adf>:89: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-3)
# <ipython-input-2-f2927eac8adf>:120: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   g_scaler = torch.cuda.amp.GradScaler()
# <ipython-input-2-f2927eac8adf>:121: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   d_scaler = torch.cuda.amp.GradScaler()
#   0%|          | 0/7 [00:00<?, ?it/s]<ipython-input-2-f2927eac8adf>:54: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# <ipython-input-2-f2927eac8adf>:68: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 100%|██████████| 7/7 [00:04<00:00,  1.41it/s, D_fake=0.482, D_real=0.554]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.452, D_real=0.564]
# 100%|██████████| 7/7 [00:03<00:00,  2.32it/s, D_fake=0.421, D_real=0.578]
# 100%|██████████| 7/7 [00:03<00:00,  2.31it/s, D_fake=0.383, D_real=0.619]
# 100%|██████████| 7/7 [00:03<00:00,  2.30it/s, D_fake=0.412, D_real=0.626]
# 100%|██████████| 7/7 [00:03<00:00,  2.19it/s, D_fake=0.366, D_real=0.643]
# 100%|██████████| 7/7 [00:03<00:00,  2.26it/s, D_fake=0.357, D_real=0.649]
# 100%|██████████| 7/7 [00:03<00:00,  2.29it/s, D_fake=0.331, D_real=0.684]
# 100%|██████████| 7/7 [00:03<00:00,  2.31it/s, D_fake=0.359, D_real=0.664]
# 100%|██████████| 7/7 [00:03<00:00,  2.18it/s, D_fake=0.311, D_real=0.694]
# 100%|██████████| 7/7 [00:03<00:00,  2.20it/s, D_fake=0.306, D_real=0.681]
# 100%|██████████| 7/7 [00:03<00:00,  2.29it/s, D_fake=0.306, D_real=0.671]
# 100%|██████████| 7/7 [00:03<00:00,  2.28it/s, D_fake=0.259, D_real=0.651]
# 100%|██████████| 7/7 [00:03<00:00,  2.23it/s, D_fake=0.273, D_real=0.757]
# 100%|██████████| 7/7 [00:03<00:00,  2.22it/s, D_fake=0.259, D_real=0.746]
# 100%|██████████| 7/7 [00:03<00:00,  2.27it/s, D_fake=0.213, D_real=0.773]
# 100%|██████████| 7/7 [00:03<00:00,  2.26it/s, D_fake=0.359, D_real=0.721]
# 100%|██████████| 7/7 [00:03<00:00,  2.17it/s, D_fake=0.282, D_real=0.757]
# 100%|██████████| 7/7 [00:03<00:00,  2.18it/s, D_fake=0.213, D_real=0.75]
# 100%|██████████| 7/7 [00:03<00:00,  2.26it/s, D_fake=0.328, D_real=0.816]
# 100%|██████████| 7/7 [00:03<00:00,  2.22it/s, D_fake=0.157, D_real=0.79]
# 100%|██████████| 7/7 [00:03<00:00,  2.17it/s, D_fake=0.227, D_real=0.796]
# 100%|██████████| 7/7 [00:03<00:00,  2.16it/s, D_fake=0.162, D_real=0.808]
# 100%|██████████| 7/7 [00:03<00:00,  2.22it/s, D_fake=0.144, D_real=0.827]
# 100%|██████████| 7/7 [00:03<00:00,  2.23it/s, D_fake=0.121, D_real=0.874]
# 100%|██████████| 7/7 [00:03<00:00,  2.12it/s, D_fake=0.17, D_real=0.837]
# 100%|██████████| 7/7 [00:03<00:00,  2.19it/s, D_fake=0.123, D_real=0.884]
# 100%|██████████| 7/7 [00:03<00:00,  2.21it/s, D_fake=0.107, D_real=0.887]
# 100%|██████████| 7/7 [00:03<00:00,  2.20it/s, D_fake=0.149, D_real=0.882]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.211, D_real=0.728]
# 100%|██████████| 7/7 [00:03<00:00,  2.20it/s, D_fake=0.159, D_real=0.885]
# 100%|██████████| 7/7 [00:03<00:00,  2.21it/s, D_fake=0.107, D_real=0.873]
# [I 2024-10-18 18:31:52,143] Trial 0 finished with value: 45.73063850402832 and parameters: {'learning_rate': 0.00010347005974254278, 'batch_size': 32, 'l1_lambda': 180, 'lambda_gp': 5, 'num_epochs': 32}. Best is trial 0 with value: 45.73063850402832.
# 100%|██████████| 26/26 [00:03<00:00,  6.66it/s, D_fake=0.416, D_real=0.585]
# 100%|██████████| 26/26 [00:03<00:00,  6.84it/s, D_fake=0.327, D_real=0.685]
# 100%|██████████| 26/26 [00:03<00:00,  6.92it/s, D_fake=0.311, D_real=0.69]
# 100%|██████████| 26/26 [00:03<00:00,  6.83it/s, D_fake=0.297, D_real=0.707]
# 100%|██████████| 26/26 [00:03<00:00,  6.65it/s, D_fake=0.204, D_real=0.766]
# 100%|██████████| 26/26 [00:03<00:00,  6.87it/s, D_fake=0.199, D_real=0.812]
# 100%|██████████| 26/26 [00:03<00:00,  6.85it/s, D_fake=0.184, D_real=0.834]
# 100%|██████████| 26/26 [00:03<00:00,  6.58it/s, D_fake=0.142, D_real=0.836]
# 100%|██████████| 26/26 [00:03<00:00,  6.81it/s, D_fake=0.111, D_real=0.886]
# 100%|██████████| 26/26 [00:03<00:00,  6.77it/s, D_fake=0.0865, D_real=0.891]
# 100%|██████████| 26/26 [00:03<00:00,  6.51it/s, D_fake=0.0981, D_real=0.916]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.135, D_real=0.812]
# 100%|██████████| 26/26 [00:03<00:00,  6.68it/s, D_fake=0.0606, D_real=0.914]
# 100%|██████████| 26/26 [00:04<00:00,  6.47it/s, D_fake=0.0829, D_real=0.912]
# [I 2024-10-18 18:32:47,660] Trial 1 finished with value: 50.693482535226 and parameters: {'learning_rate': 4.67508718981734e-05, 'batch_size': 8, 'l1_lambda': 182, 'lambda_gp': 2, 'num_epochs': 14}. Best is trial 0 with value: 45.73063850402832.
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.404, D_real=0.579]
# 100%|██████████| 13/13 [00:03<00:00,  3.76it/s, D_fake=0.367, D_real=0.616]
# 100%|██████████| 13/13 [00:03<00:00,  3.70it/s, D_fake=0.368, D_real=0.637]
# 100%|██████████| 13/13 [00:03<00:00,  3.71it/s, D_fake=0.327, D_real=0.656]
# 100%|██████████| 13/13 [00:03<00:00,  3.68it/s, D_fake=0.363, D_real=0.663]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.301, D_real=0.629]
# 100%|██████████| 13/13 [00:03<00:00,  3.70it/s, D_fake=0.257, D_real=0.767]
# 100%|██████████| 13/13 [00:03<00:00,  3.84it/s, D_fake=0.281, D_real=0.759]
# 100%|██████████| 13/13 [00:03<00:00,  3.85it/s, D_fake=0.183, D_real=0.822]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.211, D_real=0.774]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.181, D_real=0.75]
# 100%|██████████| 13/13 [00:03<00:00,  3.89it/s, D_fake=0.139, D_real=0.849]
# 100%|██████████| 13/13 [00:03<00:00,  3.88it/s, D_fake=0.153, D_real=0.822]
# 100%|██████████| 13/13 [00:03<00:00,  3.74it/s, D_fake=0.104, D_real=0.894]
# 100%|██████████| 13/13 [00:03<00:00,  3.83it/s, D_fake=0.0856, D_real=0.894]
# 100%|██████████| 13/13 [00:03<00:00,  3.87it/s, D_fake=0.313, D_real=0.862]
# 100%|██████████| 13/13 [00:03<00:00,  3.88it/s, D_fake=0.093, D_real=0.918]
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.047, D_real=0.918]
# 100%|██████████| 13/13 [00:03<00:00,  3.86it/s, D_fake=0.0409, D_real=0.948]
# 100%|██████████| 13/13 [00:03<00:00,  3.87it/s, D_fake=0.0591, D_real=0.917]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0435, D_real=0.957]
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.0324, D_real=0.956]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.037, D_real=0.969]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.0319, D_real=0.972]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.0352, D_real=0.947]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0392, D_real=0.947]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.0201, D_real=0.972]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.0127, D_real=0.978]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.0198, D_real=0.981]
# [I 2024-10-18 18:34:28,625] Trial 2 finished with value: 34.15541648864746 and parameters: {'learning_rate': 0.0001703036088972932, 'batch_size': 16, 'l1_lambda': 130, 'lambda_gp': 1, 'num_epochs': 29}. Best is trial 2 with value: 34.15541648864746.
# 100%|██████████| 26/26 [00:03<00:00,  6.74it/s, D_fake=0.442, D_real=0.547]
# 100%|██████████| 26/26 [00:03<00:00,  6.65it/s, D_fake=0.361, D_real=0.649]
# 100%|██████████| 26/26 [00:03<00:00,  6.53it/s, D_fake=0.346, D_real=0.644]
# 100%|██████████| 26/26 [00:03<00:00,  6.74it/s, D_fake=0.316, D_real=0.707]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.254, D_real=0.688]
# 100%|██████████| 26/26 [00:04<00:00,  6.49it/s, D_fake=0.194, D_real=0.781]
# 100%|██████████| 26/26 [00:03<00:00,  6.75it/s, D_fake=0.191, D_real=0.799]
# 100%|██████████| 26/26 [00:03<00:00,  6.75it/s, D_fake=0.152, D_real=0.82]
# 100%|██████████| 26/26 [00:04<00:00,  6.45it/s, D_fake=0.117, D_real=0.828]
# 100%|██████████| 26/26 [00:03<00:00,  6.75it/s, D_fake=0.126, D_real=0.879]
# 100%|██████████| 26/26 [00:03<00:00,  6.76it/s, D_fake=0.12, D_real=0.884]
# 100%|██████████| 26/26 [00:03<00:00,  6.51it/s, D_fake=0.098, D_real=0.888]
# 100%|██████████| 26/26 [00:03<00:00,  6.69it/s, D_fake=0.102, D_real=0.896]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.0753, D_real=0.888]
# 100%|██████████| 26/26 [00:03<00:00,  6.54it/s, D_fake=0.0927, D_real=0.917]
# 100%|██████████| 26/26 [00:03<00:00,  6.60it/s, D_fake=0.0793, D_real=0.898]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.198, D_real=0.824]
# 100%|██████████| 26/26 [00:03<00:00,  6.59it/s, D_fake=0.11, D_real=0.91]
# 100%|██████████| 26/26 [00:03<00:00,  6.53it/s, D_fake=0.0923, D_real=0.914]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.0743, D_real=0.905]
# 100%|██████████| 26/26 [00:03<00:00,  6.67it/s, D_fake=0.0568, D_real=0.916]
# 100%|██████████| 26/26 [00:04<00:00,  6.47it/s, D_fake=0.0687, D_real=0.93]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.0539, D_real=0.948]
# 100%|██████████| 26/26 [00:03<00:00,  6.69it/s, D_fake=0.0635, D_real=0.914]
# 100%|██████████| 26/26 [00:04<00:00,  6.46it/s, D_fake=0.0427, D_real=0.955]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.0546, D_real=0.938]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.0959, D_real=0.942]
# 100%|██████████| 26/26 [00:04<00:00,  6.47it/s, D_fake=0.0551, D_real=0.942]
# 100%|██████████| 26/26 [00:03<00:00,  6.73it/s, D_fake=0.0293, D_real=0.955]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.0608, D_real=0.958]
# 100%|██████████| 26/26 [00:04<00:00,  6.45it/s, D_fake=0.0468, D_real=0.932]
# 100%|██████████| 26/26 [00:03<00:00,  6.70it/s, D_fake=0.0719, D_real=0.898]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.0254, D_real=0.979]
# 100%|██████████| 26/26 [00:03<00:00,  6.51it/s, D_fake=0.0814, D_real=0.964]
# 100%|██████████| 26/26 [00:03<00:00,  6.64it/s, D_fake=0.0295, D_real=0.975]
# 100%|██████████| 26/26 [00:03<00:00,  6.72it/s, D_fake=0.0306, D_real=0.974]
# 100%|██████████| 26/26 [00:03<00:00,  6.60it/s, D_fake=0.0374, D_real=0.964]
# 100%|██████████| 26/26 [00:03<00:00,  6.59it/s, D_fake=0.0381, D_real=0.965]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.0525, D_real=0.967]
# 100%|██████████| 26/26 [00:03<00:00,  6.63it/s, D_fake=0.029, D_real=0.969]
# 100%|██████████| 26/26 [00:03<00:00,  6.57it/s, D_fake=0.0439, D_real=0.974]
# 100%|██████████| 26/26 [00:03<00:00,  6.51it/s, D_fake=0.0353, D_real=0.954]
# 100%|██████████| 26/26 [00:03<00:00,  6.64it/s, D_fake=0.0394, D_real=0.972]
# 100%|██████████| 26/26 [00:04<00:00,  6.49it/s, D_fake=0.159, D_real=0.953]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.0402, D_real=0.966]
# 100%|██████████| 26/26 [00:03<00:00,  6.71it/s, D_fake=0.0186, D_real=0.983]
# [I 2024-10-18 18:37:30,502] Trial 3 finished with value: 16.087418419974192 and parameters: {'learning_rate': 3.1063760886137636e-05, 'batch_size': 8, 'l1_lambda': 54, 'lambda_gp': 9, 'num_epochs': 46}. Best is trial 3 with value: 16.087418419974192.
# 100%|██████████| 13/13 [00:03<00:00,  3.76it/s, D_fake=0.428, D_real=0.572]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.37, D_real=0.633]
# 100%|██████████| 13/13 [00:03<00:00,  3.84it/s, D_fake=0.36, D_real=0.68]
# 100%|██████████| 13/13 [00:03<00:00,  3.68it/s, D_fake=0.285, D_real=0.708]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.324, D_real=0.675]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.361, D_real=0.7]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.285, D_real=0.684]
# 100%|██████████| 13/13 [00:03<00:00,  3.68it/s, D_fake=0.277, D_real=0.712]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.213, D_real=0.773]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.286, D_real=0.667]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.21, D_real=0.772]
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.2, D_real=0.805]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.157, D_real=0.82]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.14, D_real=0.859]
# 100%|██████████| 13/13 [00:03<00:00,  3.68it/s, D_fake=0.154, D_real=0.831]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0956, D_real=0.87]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.101, D_real=0.902]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.245, D_real=0.644]
# 100%|██████████| 13/13 [00:03<00:00,  3.71it/s, D_fake=0.0917, D_real=0.902]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.0757, D_real=0.907]
# [I 2024-10-18 18:38:41,212] Trial 4 finished with value: 15.73691463470459 and parameters: {'learning_rate': 0.00010934915520199043, 'batch_size': 16, 'l1_lambda': 64, 'lambda_gp': 1, 'num_epochs': 20}. Best is trial 4 with value: 15.73691463470459.
# 100%|██████████| 7/7 [00:03<00:00,  2.12it/s, D_fake=0.371, D_real=0.563]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.489, D_real=0.457]
# 100%|██████████| 7/7 [00:03<00:00,  2.11it/s, D_fake=0.484, D_real=0.546]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.476, D_real=0.562]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.515, D_real=0.537]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.453, D_real=0.553]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.409, D_real=0.562]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.395, D_real=0.574]
# 100%|██████████| 7/7 [00:03<00:00,  2.00it/s, D_fake=0.382, D_real=0.597]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.324, D_real=0.692]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.302, D_real=0.547]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.312, D_real=0.617]
# 100%|██████████| 7/7 [00:03<00:00,  1.98it/s, D_fake=0.394, D_real=0.629]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.282, D_real=0.624]
# 100%|██████████| 7/7 [00:03<00:00,  2.11it/s, D_fake=0.2, D_real=0.715]
# 100%|██████████| 7/7 [00:03<00:00,  2.04it/s, D_fake=0.215, D_real=0.781]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.261, D_real=0.632]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.143, D_real=0.787]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.433, D_real=0.628]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.106, D_real=0.834]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.177, D_real=0.594]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.161, D_real=0.816]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0842, D_real=0.882]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.0818, D_real=0.864]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.0792, D_real=0.932]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.0613, D_real=0.943]
# 100%|██████████| 7/7 [00:03<00:00,  2.04it/s, D_fake=0.257, D_real=0.651]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.191, D_real=0.745]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0977, D_real=0.864]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.148, D_real=0.898]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.0668, D_real=0.859]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.282, D_real=0.705]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.146, D_real=0.861]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.0752, D_real=0.906]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.151, D_real=0.868]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0535, D_real=0.952]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0781, D_real=0.904]
# 100%|██████████| 7/7 [00:03<00:00,  1.99it/s, D_fake=0.0347, D_real=0.945]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.0445, D_real=0.888]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.0352, D_real=0.958]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.022, D_real=0.963]
# 100%|██████████| 7/7 [00:03<00:00,  2.00it/s, D_fake=0.0338, D_real=0.976]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0168, D_real=0.994]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0109, D_real=0.993]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0106, D_real=0.989]
# 100%|██████████| 7/7 [00:03<00:00,  2.03it/s, D_fake=0.0132, D_real=0.993]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.0264, D_real=0.936]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.144, D_real=0.693]
# [I 2024-10-18 18:41:25,639] Trial 5 finished with value: 26.978636741638184 and parameters: {'learning_rate': 0.0008038367981744088, 'batch_size': 32, 'l1_lambda': 106, 'lambda_gp': 6, 'num_epochs': 48}. Best is trial 4 with value: 15.73691463470459.
# 100%|██████████| 7/7 [00:03<00:00,  1.97it/s, D_fake=0.55, D_real=0.49]
# 100%|██████████| 7/7 [00:03<00:00,  2.12it/s, D_fake=0.491, D_real=0.521]
# 100%|██████████| 7/7 [00:03<00:00,  2.11it/s, D_fake=0.446, D_real=0.534]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.39, D_real=0.529]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.364, D_real=0.634]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.416, D_real=0.571]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.459, D_real=0.558]
# 100%|██████████| 7/7 [00:03<00:00,  2.04it/s, D_fake=0.39, D_real=0.567]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.286, D_real=0.585]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.337, D_real=0.537]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.372, D_real=0.534]
# 100%|██████████| 7/7 [00:03<00:00,  1.99it/s, D_fake=0.326, D_real=0.558]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.407, D_real=0.595]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.36, D_real=0.593]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.234, D_real=0.566]
# 100%|██████████| 7/7 [00:03<00:00,  2.03it/s, D_fake=0.391, D_real=0.417]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.349, D_real=0.562]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.308, D_real=0.556]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.316, D_real=0.695]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.3, D_real=0.722]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.376, D_real=0.431]
# 100%|██████████| 7/7 [00:03<00:00,  2.12it/s, D_fake=0.308, D_real=0.678]
# 100%|██████████| 7/7 [00:03<00:00,  2.00it/s, D_fake=0.28, D_real=0.656]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.158, D_real=0.788]
# 100%|██████████| 7/7 [00:03<00:00,  2.12it/s, D_fake=0.325, D_real=0.617]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.282, D_real=0.584]
# 100%|██████████| 7/7 [00:03<00:00,  2.04it/s, D_fake=0.255, D_real=0.752]
# 100%|██████████| 7/7 [00:03<00:00,  2.11it/s, D_fake=0.211, D_real=0.613]
# [I 2024-10-18 18:43:02,339] Trial 6 finished with value: 39.10342979431152 and parameters: {'learning_rate': 0.0004525061471687337, 'batch_size': 32, 'l1_lambda': 151, 'lambda_gp': 7, 'num_epochs': 28}. Best is trial 4 with value: 15.73691463470459.
# 100%|██████████| 13/13 [00:03<00:00,  3.83it/s, D_fake=0.429, D_real=0.561]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.438, D_real=0.552]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.35, D_real=0.637]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.415, D_real=0.641]
# 100%|██████████| 13/13 [00:03<00:00,  3.74it/s, D_fake=0.369, D_real=0.728]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.303, D_real=0.656]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.381, D_real=0.62]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.217, D_real=0.77]
# 100%|██████████| 13/13 [00:03<00:00,  3.67it/s, D_fake=0.213, D_real=0.78]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.298, D_real=0.781]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.305, D_real=0.75]
# 100%|██████████| 13/13 [00:03<00:00,  3.71it/s, D_fake=0.215, D_real=0.835]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.139, D_real=0.86]
# 100%|██████████| 13/13 [00:03<00:00,  3.83it/s, D_fake=0.153, D_real=0.812]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.139, D_real=0.878]
# [I 2024-10-18 18:43:55,402] Trial 7 finished with value: 40.12102699279785 and parameters: {'learning_rate': 0.00015780526381193677, 'batch_size': 16, 'l1_lambda': 139, 'lambda_gp': 7, 'num_epochs': 15}. Best is trial 4 with value: 15.73691463470459.
# 100%|██████████| 7/7 [00:03<00:00,  2.00it/s, D_fake=0.48, D_real=0.498]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.458, D_real=0.55]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.409, D_real=0.594]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.39, D_real=0.64]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.397, D_real=0.625]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.361, D_real=0.631]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.357, D_real=0.66]
# 100%|██████████| 7/7 [00:03<00:00,  2.04it/s, D_fake=0.325, D_real=0.624]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.285, D_real=0.663]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.39, D_real=0.699]
# 100%|██████████| 7/7 [00:03<00:00,  2.05it/s, D_fake=0.282, D_real=0.738]
# 100%|██████████| 7/7 [00:03<00:00,  1.99it/s, D_fake=0.219, D_real=0.743]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.323, D_real=0.768]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.193, D_real=0.79]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.263, D_real=0.805]
# 100%|██████████| 7/7 [00:03<00:00,  2.05it/s, D_fake=0.209, D_real=0.817]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.222, D_real=0.82]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.184, D_real=0.781]
# 100%|██████████| 7/7 [00:03<00:00,  2.03it/s, D_fake=0.139, D_real=0.837]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.124, D_real=0.845]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.0911, D_real=0.837]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.152, D_real=0.859]
# 100%|██████████| 7/7 [00:03<00:00,  1.98it/s, D_fake=0.187, D_real=0.768]
# 100%|██████████| 7/7 [00:03<00:00,  2.11it/s, D_fake=0.129, D_real=0.89]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.121, D_real=0.795]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.104, D_real=0.888]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.106, D_real=0.882]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.109, D_real=0.906]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.107, D_real=0.908]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.0865, D_real=0.898]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.0684, D_real=0.786]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.0857, D_real=0.934]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0728, D_real=0.925]
# 100%|██████████| 7/7 [00:03<00:00,  1.95it/s, D_fake=0.0576, D_real=0.927]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.0537, D_real=0.943]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.0594, D_real=0.948]
# 100%|██████████| 7/7 [00:03<00:00,  2.06it/s, D_fake=0.0883, D_real=0.881]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.047, D_real=0.946]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.0552, D_real=0.935]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.123, D_real=0.956]
# 100%|██████████| 7/7 [00:03<00:00,  1.99it/s, D_fake=0.0363, D_real=0.936]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0377, D_real=0.966]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.041, D_real=0.963]
# 100%|██████████| 7/7 [00:03<00:00,  2.05it/s, D_fake=0.0389, D_real=0.959]
# [I 2024-10-18 18:46:26,496] Trial 8 finished with value: 41.612945556640625 and parameters: {'learning_rate': 9.208078691839114e-05, 'batch_size': 32, 'l1_lambda': 150, 'lambda_gp': 9, 'num_epochs': 44}. Best is trial 4 with value: 15.73691463470459.
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.382, D_real=0.521]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.505, D_real=0.462]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.455, D_real=0.598]
# 100%|██████████| 7/7 [00:03<00:00,  1.99it/s, D_fake=0.48, D_real=0.547]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.427, D_real=0.523]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.393, D_real=0.576]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.412, D_real=0.569]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.42, D_real=0.62]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.43, D_real=0.58]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.402, D_real=0.578]
# 100%|██████████| 7/7 [00:03<00:00,  2.03it/s, D_fake=0.353, D_real=0.647]
# 100%|██████████| 7/7 [00:03<00:00,  2.04it/s, D_fake=0.4, D_real=0.556]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.441, D_real=0.65]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.279, D_real=0.641]
# 100%|██████████| 7/7 [00:03<00:00,  2.02it/s, D_fake=0.234, D_real=0.718]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.252, D_real=0.705]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.237, D_real=0.728]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.172, D_real=0.739]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.155, D_real=0.763]
# 100%|██████████| 7/7 [00:03<00:00,  2.07it/s, D_fake=0.165, D_real=0.825]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.439, D_real=0.594]
# 100%|██████████| 7/7 [00:03<00:00,  2.01it/s, D_fake=0.252, D_real=0.724]
# 100%|██████████| 7/7 [00:03<00:00,  2.05it/s, D_fake=0.21, D_real=0.642]
# 100%|██████████| 7/7 [00:03<00:00,  2.10it/s, D_fake=0.0714, D_real=0.815]
# 100%|██████████| 7/7 [00:03<00:00,  2.08it/s, D_fake=0.0732, D_real=0.913]
# 100%|██████████| 7/7 [00:03<00:00,  1.99it/s, D_fake=0.0379, D_real=0.97]
# 100%|██████████| 7/7 [00:03<00:00,  2.09it/s, D_fake=0.0581, D_real=0.523]
# [I 2024-10-18 18:47:59,790] Trial 9 finished with value: 31.789319038391113 and parameters: {'learning_rate': 0.000864262436909769, 'batch_size': 32, 'l1_lambda': 115, 'lambda_gp': 3, 'num_epochs': 27}. Best is trial 4 with value: 15.73691463470459.
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.479, D_real=0.527]
# 100%|██████████| 13/13 [00:03<00:00,  3.65it/s, D_fake=0.452, D_real=0.566]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.414, D_real=0.584]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.393, D_real=0.604]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.377, D_real=0.625]
# [I 2024-10-18 18:48:18,623] Trial 10 finished with value: 4.444215893745422 and parameters: {'learning_rate': 1.37913294035612e-05, 'batch_size': 16, 'l1_lambda': 14, 'lambda_gp': 4, 'num_epochs': 5}. Best is trial 10 with value: 4.444215893745422.
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.478, D_real=0.528]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.461, D_real=0.549]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.438, D_real=0.577]
# 100%|██████████| 13/13 [00:03<00:00,  3.65it/s, D_fake=0.424, D_real=0.568]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.391, D_real=0.616]
# [I 2024-10-18 18:48:37,713] Trial 11 finished with value: 3.7470269203186035 and parameters: {'learning_rate': 1.2866524809909697e-05, 'batch_size': 16, 'l1_lambda': 12, 'lambda_gp': 4, 'num_epochs': 5}. Best is trial 11 with value: 3.7470269203186035.
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.481, D_real=0.521]
# 100%|██████████| 13/13 [00:03<00:00,  3.65it/s, D_fake=0.467, D_real=0.545]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.448, D_real=0.561]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.419, D_real=0.596]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.417, D_real=0.598]
# [I 2024-10-18 18:48:56,338] Trial 12 finished with value: 3.5833725929260254 and parameters: {'learning_rate': 1.0712453846274215e-05, 'batch_size': 16, 'l1_lambda': 11, 'lambda_gp': 4, 'num_epochs': 5}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.48, D_real=0.528]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.454, D_real=0.563]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.431, D_real=0.585]
# 100%|██████████| 13/13 [00:03<00:00,  3.67it/s, D_fake=0.412, D_real=0.595]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.384, D_real=0.619]
# [I 2024-10-18 18:49:15,169] Trial 13 finished with value: 8.849631309509277 and parameters: {'learning_rate': 1.3468857076079071e-05, 'batch_size': 16, 'l1_lambda': 27, 'lambda_gp': 4, 'num_epochs': 5}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.49, D_real=0.531]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.473, D_real=0.542]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.458, D_real=0.558]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.443, D_real=0.576]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.433, D_real=0.59]
# 100%|██████████| 13/13 [00:03<00:00,  3.67it/s, D_fake=0.421, D_real=0.604]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.405, D_real=0.62]
# 100%|██████████| 13/13 [00:03<00:00,  3.75it/s, D_fake=0.372, D_real=0.632]
# 100%|██████████| 13/13 [00:03<00:00,  3.67it/s, D_fake=0.363, D_real=0.653]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.348, D_real=0.658]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.319, D_real=0.683]
# [I 2024-10-18 18:49:54,503] Trial 14 finished with value: 22.3882737159729 and parameters: {'learning_rate': 1.008064061646486e-05, 'batch_size': 16, 'l1_lambda': 68, 'lambda_gp': 3, 'num_epochs': 11}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 13/13 [00:03<00:00,  3.75it/s, D_fake=0.465, D_real=0.554]
# 100%|██████████| 13/13 [00:03<00:00,  3.57it/s, D_fake=0.417, D_real=0.584]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.388, D_real=0.616]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.348, D_real=0.654]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.331, D_real=0.659]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.318, D_real=0.68]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.282, D_real=0.713]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.255, D_real=0.727]
# 100%|██████████| 13/13 [00:03<00:00,  3.63it/s, D_fake=0.253, D_real=0.735]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.206, D_real=0.754]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.214, D_real=0.781]
# 100%|██████████| 13/13 [00:03<00:00,  3.74it/s, D_fake=0.192, D_real=0.808]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.198, D_real=0.805]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.168, D_real=0.812]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.156, D_real=0.832]
# 100%|██████████| 13/13 [00:03<00:00,  3.62it/s, D_fake=0.178, D_real=0.832]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.159, D_real=0.839]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.133, D_real=0.841]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.167, D_real=0.875]
# [I 2024-10-18 18:51:01,681] Trial 15 finished with value: 12.478726863861084 and parameters: {'learning_rate': 2.530067928827896e-05, 'batch_size': 16, 'l1_lambda': 38, 'lambda_gp': 5, 'num_epochs': 19}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 26/26 [00:03<00:00,  6.60it/s, D_fake=0.457, D_real=0.548]
# 100%|██████████| 26/26 [00:03<00:00,  6.64it/s, D_fake=0.402, D_real=0.589]
# 100%|██████████| 26/26 [00:03<00:00,  6.54it/s, D_fake=0.342, D_real=0.676]
# 100%|██████████| 26/26 [00:03<00:00,  6.52it/s, D_fake=0.331, D_real=0.677]
# 100%|██████████| 26/26 [00:03<00:00,  6.63it/s, D_fake=0.312, D_real=0.656]
# 100%|██████████| 26/26 [00:03<00:00,  6.59it/s, D_fake=0.281, D_real=0.718]
# 100%|██████████| 26/26 [00:04<00:00,  6.48it/s, D_fake=0.228, D_real=0.768]
# 100%|██████████| 26/26 [00:03<00:00,  6.65it/s, D_fake=0.223, D_real=0.769]
# 100%|██████████| 26/26 [00:03<00:00,  6.60it/s, D_fake=0.198, D_real=0.805]
# [I 2024-10-18 18:51:38,864] Trial 16 finished with value: 27.777877807617188 and parameters: {'learning_rate': 2.1273006695370232e-05, 'batch_size': 8, 'l1_lambda': 80, 'lambda_gp': 7, 'num_epochs': 9}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.443, D_real=0.561]
# 100%|██████████| 13/13 [00:03<00:00,  3.82it/s, D_fake=0.395, D_real=0.618]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.366, D_real=0.63]
# 100%|██████████| 13/13 [00:03<00:00,  3.64it/s, D_fake=0.346, D_real=0.675]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.31, D_real=0.688]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.321, D_real=0.671]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.278, D_real=0.678]
# 100%|██████████| 13/13 [00:03<00:00,  3.74it/s, D_fake=0.24, D_real=0.743]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.267, D_real=0.752]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.208, D_real=0.768]
# 100%|██████████| 13/13 [00:03<00:00,  3.66it/s, D_fake=0.21, D_real=0.79]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.176, D_real=0.802]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.208, D_real=0.823]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.153, D_real=0.838]
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.196, D_real=0.827]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.13, D_real=0.854]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.115, D_real=0.867]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.135, D_real=0.88]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.145, D_real=0.808]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0741, D_real=0.92]
# 100%|██████████| 13/13 [00:03<00:00,  3.74it/s, D_fake=0.0811, D_real=0.919]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.0712, D_real=0.934]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.182, D_real=0.803]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.0878, D_real=0.882]
# 100%|██████████| 13/13 [00:03<00:00,  3.67it/s, D_fake=0.0723, D_real=0.922]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0639, D_real=0.924]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.0637, D_real=0.926]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.0833, D_real=0.903]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.0577, D_real=0.942]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0836, D_real=0.919]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0486, D_real=0.942]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.0446, D_real=0.951]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.0351, D_real=0.956]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.0464, D_real=0.948]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0569, D_real=0.945]
# 100%|██████████| 13/13 [00:03<00:00,  3.69it/s, D_fake=0.0353, D_real=0.962]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.0461, D_real=0.952]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.0354, D_real=0.953]
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.0562, D_real=0.903]
# [I 2024-10-18 18:53:55,633] Trial 17 finished with value: 4.4058849811553955 and parameters: {'learning_rate': 4.7972226161836635e-05, 'batch_size': 16, 'l1_lambda': 16, 'lambda_gp': 3, 'num_epochs': 39}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 13/13 [00:03<00:00,  3.83it/s, D_fake=0.447, D_real=0.551]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.387, D_real=0.614]
# 100%|██████████| 13/13 [00:03<00:00,  3.73it/s, D_fake=0.337, D_real=0.642]
# 100%|██████████| 13/13 [00:03<00:00,  3.58it/s, D_fake=0.327, D_real=0.654]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.312, D_real=0.695]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.313, D_real=0.667]
# 100%|██████████| 13/13 [00:03<00:00,  3.67it/s, D_fake=0.327, D_real=0.686]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.299, D_real=0.71]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.299, D_real=0.71]
# 100%|██████████| 13/13 [00:03<00:00,  3.77it/s, D_fake=0.286, D_real=0.756]
# 100%|██████████| 13/13 [00:03<00:00,  3.72it/s, D_fake=0.304, D_real=0.717]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.277, D_real=0.755]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.252, D_real=0.755]
# 100%|██████████| 13/13 [00:03<00:00,  3.66it/s, D_fake=0.274, D_real=0.763]
# 100%|██████████| 13/13 [00:03<00:00,  3.78it/s, D_fake=0.215, D_real=0.78]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.235, D_real=0.759]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.244, D_real=0.781]
# 100%|██████████| 13/13 [00:03<00:00,  3.71it/s, D_fake=0.179, D_real=0.821]
# 100%|██████████| 13/13 [00:03<00:00,  3.83it/s, D_fake=0.159, D_real=0.833]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.147, D_real=0.838]
# 100%|██████████| 13/13 [00:03<00:00,  3.75it/s, D_fake=0.186, D_real=0.778]
# 100%|██████████| 13/13 [00:03<00:00,  3.79it/s, D_fake=0.127, D_real=0.867]
# [I 2024-10-18 18:55:12,957] Trial 18 finished with value: 21.939606189727783 and parameters: {'learning_rate': 4.4068079369762145e-05, 'batch_size': 16, 'l1_lambda': 88, 'lambda_gp': 4, 'num_epochs': 22}. Best is trial 12 with value: 3.5833725929260254.
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.477, D_real=0.528]
# 100%|██████████| 13/13 [00:03<00:00,  3.71it/s, D_fake=0.445, D_real=0.564]
# 100%|██████████| 13/13 [00:03<00:00,  3.70it/s, D_fake=0.419, D_real=0.602]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.385, D_real=0.609]
# 100%|██████████| 13/13 [00:03<00:00,  3.80it/s, D_fake=0.369, D_real=0.642]
# 100%|██████████| 13/13 [00:03<00:00,  3.68it/s, D_fake=0.331, D_real=0.657]
# 100%|██████████| 13/13 [00:03<00:00,  3.75it/s, D_fake=0.311, D_real=0.708]
# 100%|██████████| 13/13 [00:03<00:00,  3.81it/s, D_fake=0.288, D_real=0.711]
# 100%|██████████| 13/13 [00:03<00:00,  3.74it/s, D_fake=0.299, D_real=0.713]
# 100%|██████████| 13/13 [00:03<00:00,  3.71it/s, D_fake=0.301, D_real=0.714]
# [I 2024-10-18 18:55:48,956] Trial 19 finished with value: 15.149436712265015 and parameters: {'learning_rate': 1.8087639626014292e-05, 'batch_size': 16, 'l1_lambda': 49, 'lambda_gp': 6, 'num_epochs': 10}. Best is trial 12 with value: 3.5833725929260254.
# Best Hyperparameters:  {'learning_rate': 1.0712453846274215e-05, 'batch_size': 16, 'l1_lambda': 11, 'lambda_gp': 4, 'num_epochs': 5}
